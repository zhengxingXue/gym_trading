# %%
# %matplotlib inline
import gym
import gym_trading
import numpy as np

from stable_baselines import PPO2
from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common.evaluation import evaluate_policy
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
env = gym.make('StockTrading-IBM-MSFT-v1')

# %%
env.render()

# %%
for _ in range(150):
    env.step(env.action_space.sample())
env.render(label_action=False)

# %%
ENV_NAME = 'StockTrading-IBM-MSFT-v1'

# %%
num_envs = 8
env = gym.make(ENV_NAME)
env = DummyVecEnv([lambda: env] * num_envs)

# %%
model = PPO2(MlpPolicy, env, verbose=1)

# %%
env = gym.make(ENV_NAME)
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=50, deterministic=False)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
model.learn(total_timesteps=10**4)

# %%
env = gym.make(ENV_NAME)
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=50, deterministic=False)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
env = gym.make(ENV_NAME)
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=50, deterministic=False)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")

# %%
env.render()

# %%
for _ in range(150):
    env.step(env.action_space.sample())
env.render(label_action=False)

# %%
ENV_NAME = 'StockTrading-IBM-MSFT-v1'

# %%
num_envs = 8
env = gym.make(ENV_NAME)
env = DummyVecEnv([lambda: env] * num_envs)

# %%
model = PPO2(MlpPolicy, env, verbose=1)
# Out:
# WARNING:tensorflow:From /Users/jim/Library/Python/3.7/lib/python/site-packages/stable_baselines/common/tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /Users/jim/Library/Python/3.7/lib/python/site-packages/stable_baselines/common/tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /Users/jim/Library/Python/3.7/lib/python/site-packages/stable_baselines/common/policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /Users/jim/Library/Python/3.7/lib/python/site-packages/stable_baselines/common/input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /Users/jim/Library/Python/3.7/lib/python/site-packages/stable_baselines/common/policies.py:561: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /opt/local/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow_core/python/layers/core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /Users/jim/Library/Python/3.7/lib/python/site-packages/stable_baselines/common/tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /Users/jim/Library/Python/3.7/lib/python/site-packages/stable_baselines/common/distributions.py:326: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /Users/jim/Library/Python/3.7/lib/python/site-packages/stable_baselines/common/distributions.py:327: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /Users/jim/Library/Python/3.7/lib/python/site-packages/stable_baselines/ppo2/ppo2.py:190: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /Users/jim/Library/Python/3.7/lib/python/site-packages/stable_baselines/ppo2/ppo2.py:198: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From /opt/local/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /Users/jim/Library/Python/3.7/lib/python/site-packages/stable_baselines/ppo2/ppo2.py:206: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /Users/jim/Library/Python/3.7/lib/python/site-packages/stable_baselines/ppo2/ppo2.py:240: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /Users/jim/Library/Python/3.7/lib/python/site-packages/stable_baselines/ppo2/ppo2.py:242: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.

# %%
env = gym.make(ENV_NAME)
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=50, deterministic=False)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:24.10 +/- 212.99

# %%
model.learn(total_timesteps=10**4)
# Out:
# --------------------------------------
# | approxkl           | 0.0005453811  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.000335     |
# | fps                | 839           |
# | n_updates          | 1             |
# | policy_entropy     | 2.19638       |
# | policy_loss        | -0.0017295397 |
# | serial_timesteps   | 128           |
# | time_elapsed       | 2.48e-05      |
# | total_timesteps    | 1024          |
# | value_loss         | 1415.7605     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 7.9342724e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 2.27e-05      |
# | fps                | 1601          |
# | n_updates          | 2             |
# | policy_entropy     | 2.195104      |
# | policy_loss        | 0.00025619054 |
# | serial_timesteps   | 256           |
# | time_elapsed       | 1.22          |
# | total_timesteps    | 2048          |
# | value_loss         | 1381.3094     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 6.998773e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.000223      |
# | fps                | 1723          |
# | n_updates          | 3             |
# | policy_entropy     | 2.1942017     |
# | policy_loss        | -0.0009939332 |
# | serial_timesteps   | 384           |
# | time_elapsed       | 1.86          |
# | total_timesteps    | 3072          |
# | value_loss         | 1079.9507     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.7896982e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.000725      |
# | fps                | 1752          |
# | n_updates          | 4             |
# | policy_entropy     | 2.1928923     |
# | policy_loss        | -3.838286e-05 |
# | serial_timesteps   | 512           |
# | time_elapsed       | 2.46          |
# | total_timesteps    | 4096          |
# | value_loss         | 749.88855     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00013016953 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.000255     |
# | fps                | 1632          |
# | n_updates          | 5             |
# | policy_entropy     | 2.194097      |
# | policy_loss        | -0.0007409574 |
# | serial_timesteps   | 640           |
# | time_elapsed       | 3.04          |
# | total_timesteps    | 5120          |
# | value_loss         | 644.2997      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00055637164 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00148      |
# | fps                | 1594          |
# | n_updates          | 6             |
# | policy_entropy     | 2.1954694     |
# | policy_loss        | -0.0018431155 |
# | serial_timesteps   | 768           |
# | time_elapsed       | 3.67          |
# | total_timesteps    | 6144          |
# | value_loss         | 527.77435     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00013774773  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.000811      |
# | fps                | 1544           |
# | n_updates          | 7              |
# | policy_entropy     | 2.1943176      |
# | policy_loss        | -0.00021212595 |
# | serial_timesteps   | 896            |
# | time_elapsed       | 4.31           |
# | total_timesteps    | 7168           |
# | value_loss         | 483.57025      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 9.47657e-05    |
# | clipfrac           | 0.0            |
# | explained_variance | 0.000239       |
# | fps                | 1452           |
# | n_updates          | 8              |
# | policy_entropy     | 2.1949904      |
# | policy_loss        | -0.00055253523 |
# | serial_timesteps   | 1024           |
# | time_elapsed       | 4.98           |
# | total_timesteps    | 8192           |
# | value_loss         | 1458.4205      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 3.9676415e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.000269      |
# | fps                | 1431          |
# | n_updates          | 9             |
# | policy_entropy     | 2.1956177     |
# | policy_loss        | -0.0005562582 |
# | serial_timesteps   | 1152          |
# | time_elapsed       | 5.68          |
# | total_timesteps    | 9216          |
# | value_loss         | 967.39685     |
# --------------------------------------

# %%
env = gym.make(ENV_NAME)
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=50, deterministic=False)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-13.99 +/- 194.58
